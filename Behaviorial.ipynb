# %% [markdown]
# ## behavioural

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("B dataSet1.csv")

# %%
data.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan  Total Salary    Price
# 0           Yes        800000   800000
# 1           Yes       2000000  1000000
# 2           Yes       1800000  1200000
# 3            No       2200000  1200000
# 4           Yes       2600000  1600000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               99 non-null     int64
#  1   Profession        99 non-null     object
#  2   Marrital Status   99 non-null     object
#  3   Education         99 non-null     object
#  4   No of Dependents  99 non-null     int64
#  5   Personal loan     99 non-null     object
#  6   Total Salary      99 non-null     int64
#  7   Price             99 non-null     int64
# dtypes: int64(4), object(4)
# memory usage: 6.3+ KB

# %%
data.shape
# Out:
# (99, 8)

# %%
data.isnull().sum()
# Out:
# Age                 0
# Profession          0
# Marrital Status     0
# Education           0
# No of Dependents    0
# Personal loan       0
# Total Salary        0
# Price               0
# dtype: int64

# %%
data.describe()
# Out:
#              Age  No of Dependents  Total Salary         Price
# count  99.000000         99.000000  9.900000e+01  9.900000e+01
# mean   36.313131          2.181818  2.270707e+06  1.194040e+06
# std     6.246054          1.335265  1.050777e+06  4.376955e+05
# min    26.000000          0.000000  2.000000e+05  1.100000e+05
# 25%    31.000000          2.000000  1.550000e+06  8.000000e+05
# 50%    36.000000          2.000000  2.100000e+06  1.200000e+06
# 75%    41.000000          3.000000  2.700000e+06  1.500000e+06
# max    51.000000          4.000000  5.200000e+06  3.000000e+06

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'No of Dependents'}>],
#        [<Axes: title={'center': 'Total Salary'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %%
# Identify numeric columns
numeric_columns = data.select_dtypes(include=['int64', 'float64']).columns

for column in numeric_columns:
    plt.figure(figsize=(4, 4))
    plt.bar(data.index, data[column])
    plt.title(f'Distribution of {column}')
    plt.xlabel('Index')
    plt.ylabel(column)
    plt.show()

# %%
age_counts = data['Age'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.bar(age_counts.index, age_counts.values, color='grey')
plt.ylabel("Age")
plt.xlabel("Number of People")
plt.title("Number of People by Age")
plt.show()

# %%
# Count the number of times each salary appears in the DataFrame
salary_counts = data["Total Salary"].value_counts(normalize=True)

# Create a bar graph
plt.bar(salary_counts.index/100000, salary_counts.values, color='red')
plt.xlabel("Salary in 100000")
plt.ylabel("Proportion of People")
plt.title("Distribution of Salary")

# Show the plot
plt.show()

# %%
Car_count = data['Price'].value_counts()
plt.bar(Car_count.index/10000, Car_count.values, color='black')
plt.xlabel("Car Price in 10000")
plt.ylabel("Proportion of Car")
plt.title("Distribution of Car Price")

# Show the plot
plt.show()

# %%
age_category_counts = data.groupby(['Age', 'No of Dependents']).size().unstack(fill_value=0)


age_category_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.xlabel("Age")
plt.ylabel("Number of People")
plt.title("Number of People by Age and Category")
plt.legend(title='Category')
plt.show()

# %%
sns.countplot(x='Marrital Status', data=data)
plt.xlabel('Marrital Status')
plt.ylabel('Count')
plt.title('Count Plot of Marrital Status')
plt.show()

# %%
ax = sns.countplot(x='No of Dependents', data=data)

# Calculate the total count
total = len(data)

# Iterate through the patches (bars) in the count plot to add annotations
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total) * 100
    ax.annotate(f'{height}\n({percentage:.1f}%)',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center',
                xytext=(0, 5), textcoords='offset points')

plt.xlabel('No of No of Dependents')
plt.ylabel('Count')
plt.title('Count Plot of Dependents with Percentages')
plt.show()

# %%
ax = sns.countplot(x='Education', data=data)

# Calculate the total count
total = len(data)

# Iterate through the patches (bars) in the count plot to add annotations
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total) * 100
    ax.annotate(f'{height}\n({percentage:.1f}%)',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center',
                xytext=(0, 5), textcoords='offset points')

plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Count Plot of Education Status with Percentages')
plt.show()

# %%
ax = sns.countplot(x='Education', data=data)

# Calculate the total count
total = len(data)

# Iterate through the patches (bars) in the count plot to add annotations
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total) * 100
    ax.annotate(f'{height}\n({percentage:.1f}%)',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center',
                xytext=(0, 5), textcoords='offset points')

plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Count Plot of Education Status with Percentages')
plt.show()

# %%
category_counts = data['Personal loan'].value_counts()

plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff'])
plt.legend(category_counts.index, title='Personal Loan', loc='upper right')

plt.show()

# %%
Profession_ = data['Profession'].value_counts()
plt.pie(Profession_ , labels= Profession_.index, autopct='%1.1f%%', colors=['#ff6347', '#4682b4'])
plt.legend(Profession_.index, title= 'Profession', loc='upper left')
plt.show()

# %%
# !pip install kmodes
from kmodes.kprototypes import KPrototypes

import plotly.express as px
import plotly.io as poi

# %%
cluster_features = list(data.columns)
cluster_data = data[cluster_features].values
cluster_data[:, 0] = cluster_data[:, 0].astype(float)
cluster_data[:, 4] = cluster_data[:, 4].astype(float)
cluster_data[:, 6] = cluster_data[:, 6].astype(float)
cluster_data[:, 7] = cluster_data[:, 7].astype(float)
# Finding optimal number of clusters for KPrototypes

cost = []
for num_clusters in list(range(1,8)):
    kproto = KPrototypes(n_clusters=num_clusters, init='Cao')
    kproto.fit_predict(cluster_data, categorical=[1,2,3,5])
    cost.append(kproto.cost_)

plt.plot(cost)

# %%
# fitting data to clusters

kproto = KPrototypes(n_clusters=2, verbose=2,max_iter=20)
clusters = kproto.fit_predict(cluster_data, categorical=[1,2,3,5])
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 3, ncost: 49051024054045.22
# Run: 1, iteration: 2/20, moves: 3, ncost: 48631729380526.18
# Run: 1, iteration: 3/20, moves: 0, ncost: 48631729380526.18
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 18, ncost: 50447073534650.24
# Run: 2, iteration: 2/20, moves: 3, ncost: 50057040964014.66
# Run: 2, iteration: 3/20, moves: 1, ncost: 50020391397205.32
# Run: 2, iteration: 4/20, moves: 0, ncost: 50020391397205.32
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 3, ncost: 50057040964014.66
# Run: 3, iteration: 2/20, moves: 1, ncost: 50020391397205.32
# Run: 3, iteration: 3/20, moves: 0, ncost: 50020391397205.32
# Init: initializing centroids
# ...

# %%
# Appending the cluster data

data['Cluster'] = clusters
# Average cost of the EV
data.Price.mean()

# Average cost of a car in segment 1 
data.Price[data.Cluster==0].mean()
# Out:
# 1021267.6056338028

# %%
# Average cost of a car in segment 1 
data.Price[data.Cluster==0].mean()
# Out:
# 1021267.6056338028

# %%
# Average cost of a car in segment 1 
data.Price[data.Cluster==1].mean()
# Out:
# 1632142.857142857

# %%
data['Cluster'].value_counts(normalize=True) * 100
# Out:
# Cluster
# 0    71.717172
# 1    28.282828
# Name: proportion, dtype: float64

# %%
# Segregrating each cluster

Cluster_0 = data[data.Cluster==0]
Cluster_1 = data[data.Cluster==1]

# %%
data['Cluster'].value_counts()
# Out:
# Cluster
# 0    71
# 1    28
# Name: count, dtype: int64

# %%
# plotting the effct of salary and ev price on cluster data

plt.scatter(Cluster_0.Price, Cluster_0['Total Salary'],color='red', marker = 'x', label = 'Cluster 1')
plt.scatter(Cluster_1.Price, Cluster_1['Total Salary'],color='green', label = 'Cluster 2')
plt.legend(loc="upper left")

plt.xlabel('Car Price')
plt.ylabel('Total salary')
plt.show()

# %%
plt.scatter(Cluster_0.Price, Cluster_0['Age'],color='red', marker = 'x', label = 'Cluster 1')
plt.scatter(Cluster_1.Price, Cluster_1['Age'],color='green', label = 'Cluster 2')
plt.legend(loc = "upper left")

plt.xlabel('Car Price')
plt.ylabel('Age')
plt.show()

# %%
plt.scatter(Cluster_0.Price, Cluster_0['No of Dependents'],color='red', marker = 'x', label = 'Cluster 1')
plt.scatter(Cluster_1.Price, Cluster_1['No of Dependents'],color='green', label = 'Cluster 2')
plt.legend(loc = "upper left")

plt.xlabel('Car Price')
plt.ylabel('Age')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# plotting influence of age 

fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(111, projection='3d')

ax.scatter(Cluster_0.Price, Cluster_0['Total Salary'], Cluster_0['Age'], color='red', marker = 'x', label = 'Cluster 1')
ax.scatter(Cluster_1.Price, Cluster_1['Total Salary'],Cluster_1['Age'], color='green', label = 'Cluster 2')
plt.legend(loc = 'upper left')

ax.view_init(10, 20)

plt.xlabel("Car Price")
plt.ylabel("Total Salary")
ax.set_zlabel('Age')
plt.show()
